# %%
from augmentation import DataAugmentation
import torch
import cv2
import matplotlib.pyplot as plt
from torchvision import transforms

from data.dataset import LineFollowingDataset

# %%
dataset = LineFollowingDataset(root_folder="../put_jetbot_dataset/dataset", run_ids=["1652875851.3497071", "1652875901.3107166"])

# %%
to_tensor = transforms.ToTensor()
to_pil = transforms.ToPILImage()

# %%
model = DataAugmentation('extreme')

fig, axs = plt.subplots(10, 2, figsize=(10, 40))
for i in range(10):
    img, target = dataset[i]
    axs[i,0].imshow(img)
    img = to_tensor(img)
    img = torch.unsqueeze(img, 0)

    axs[i,1].imshow(to_pil(model(img)[0]))
